# %%
import pandas as pd
import spacy
from itertools import zip_longest
import re

file_path = r"C:\Users\spolo\OneDrive\Documents\DOC\Work\TCS\Code\dynamic_data_masking\presidio_ddm\deny_list_dataset\deny_list_tokens_ddm.xlsx"
new_file_path = r"C:\Users\spolo\OneDrive\Documents\DOC\Work\TCS\Code\dynamic_data_masking\presidio_ddm\deny_list_dataset\deny_list_tokens_c4_v1.xlsx"

df = pd.read_excel(file_path, sheet_name="BIOMETRIC")

nlp = spacy.load("fr_core_news_lg")
french_stopwords = nlp.Defaults.stop_words

# %%
import pandas as pd
from itertools import zip_longest

def augmentation(df, french_stopwords):
    new_df_columns = {}

    for col in df.columns:
        new_column = list(df[col].dropna())  # Remove NaN values

        # Split words by space
        new_column_split = [conv.split() for conv in new_column]
        new_column_split_joined = [item for lst in new_column_split for item in lst]
        new_column.extend(new_column_split_joined)

        # Remove French stopwords
        new_column = [word for word in new_column if word.lower() not in french_stopwords]

        # Handle hyphenated words
        split = [sub.split("-") for sub in new_column if '-' in sub]
        new_subcat = [item for lst in split for item in lst]
        new_column.extend(new_subcat)

        # Lowercase transformation
        new_column_lower = [word.lower() for word in new_column]
        new_column.extend(new_column_lower)

        # Remove stopwords again after modifications
        new_column = [word for word in new_column if word.lower() not in french_stopwords]

        # Convert to unique sorted list
        new_column = sorted(set(new_column))

        # Store results in dictionary (column_name: column_values)
        new_df_columns[col] = new_column

    # Make all columns the same length using zip_longest
    max_length = max(len(v) for v in new_df_columns.values())
    for col in new_df_columns:
        new_df_columns[col] += [None] * (max_length - len(new_df_columns[col]))  # Padding with None

    # Convert dictionary to DataFrame
    new_df = pd.DataFrame(new_df_columns)

    return new_df


new_df = augmentation(df, french_stopwords)

with pd.ExcelWriter(new_file_path, mode='a', if_sheet_exists='new', engine='openpyxl') as writer:
    new_df.to_excel(writer, sheet_name='BIOMETRIC', index=False)

# %% [markdown]
# # FACE_FEATURES

# %%
conviction = list(health["FACE_FEATURES"].dropna())
conviction_split  = [conv.split() for conv in conviction]
conviction_split_joined = [item for lst in conviction_split for item  in lst]
conviction.extend(conviction_split_joined)

conviction = [word for word in  conviction if word not in french_stopwords]
split = [sub.split("-") for sub in conviction if '-' in sub]
new_subcat = [item for lst in split for item in lst]
conviction.extend(new_subcat)

conviction_lower = [word.lower() for word in conviction]
conviction.extend(conviction_lower)

conviction = [word for word in  conviction if word not in french_stopwords]
face = set(conviction)
sorted(face)
# Out:
# ['###',
#  '### Front',
#  '### front',
#  'Alignement',
#  'Alignement des dents',
#  'Alignement du visage',
#  'Analyse',
#  'Analyse du visage',
#  'Angle',
#  'Angle de la mâchoire',
#  'Angle du menton',
#  'Angle du nez',
#  'Asymétrie',
#  'Asymétrie des lèvres',
#  'Asymétrie des oreilles',
#  'Asymétrie faciale',
#  'Barbe',
#  'Base',
#  'Base du nez',
#  'Bosses',
#  'Bosses frontales',
#  'Bouche',
#  'Cartilage',
#  'Cartilage auriculaire',
#  'Cernes',
#  'Cernes sous les yeux',
#  'Cicatrices',
#  'Cicatrices faciales',
#  'Cils',
#  'Contour',
#  'Contour de la mâchoire',
#  'Contours',
#  'Contours des lèvres',
#  'Contours du visage',
#  'Couleur',
#  'Couleur des yeux',
#  'Courbure',
#  'Courbure des sourcils',
#  'Creux',
#  'Creux des joues',
#  'Cupidon',
#  'Cupidon des lèvres',
#  'Densité',
#  'Densité des sourcils',
#  'Distance',
#  'Distance interoculaire',
#  'Distance sourcils',
#  'Distance sourcils-yeux',
#  'Dorsum',
#  'Dorsum nasal',
#  'Dynamique',
#  'Dynamique du visage',
#  'Expression',
#  'Expression du regard',
#  'Expression faciale',
#  'Forme',
#  'Forme de la mâchoire',
#  'Forme des lèvres',
#  'Forme des oreilles',
#  'Forme des yeux',
#  'Forme du menton',
#  'Forme du nez',
#  'Forme du visage',
#  'Fossette',
#  'Fossette du menton',
#  'Front',
#  'Front dégagé',
#  'Grain',
#  'Grain de beauté',
#  'Grain de peau',
#  'Hauteur',
#  'Hauteur des lèvres',
#  'Hauteur des oreilles',
#  'Hauteur des pommettes',
#  'Hauteur du front',
#  'Hauteur du nez',
#  'Hauteur du visage',
#  'Implantation',
#  'Implantation capillaire',
#  'Inclinaison',
#  'Inclinaison des oreilles',
#  'Inclinaison des yeux',
#  'Inclinaison du front',
#  'Joues',
#  'Largeur',
#  'Largeur de la bouche',
#  'Largeur de la mâchoire',
#  'Largeur des oreilles',
#  'Largeur des pommettes',
#  'Largeur du front',
#  'Largeur du menton',
#  'Largeur du nez',
#  'Largeur du visage',
#  'Lignes',
#  'Lignes du front',
#  'Lobes',
#  "Lobes d'oreilles",
#  'Longueur',
#  'Longueur du nez',
#  'Longueur du visage',
#  'Mandibule',
#  'Maxillaire',
#  'Menton',
#  'Mobilité',
#  'Mobilité oculaire',
#  'Morphologie',
#  'Morphologie faciale',
#  'Moustache',
#  'Mouvement',
#  'Mouvement des lèvres',
#  'Musculature',
#  'Musculature faciale',
#  'Mâchoire',
#  'Narines',
#  'Nez',
#  'Oreilles',
#  'Os',
#  'Os du visage',
#  'Os zygomatique',
#  'Paupières',
#  'Philtrum',
#  'Photogrammétrie',
#  'Photogrammétrie faciale',
#  'Pilosité',
#  'Pilosité faciale',
#  'Plis',
#  'Plis de l’oreille',
#  'Plis des paupières',
#  'Poids',
#  'Poids du visage',
#  'Pointe',
#  'Pointe du nez',
#  'Pommettes',
#  'Pores',
#  'Pores du visage',
#  'Position',
#  'Position des oreilles',
#  'Position des paupières',
#  'Posture',
#  'Posture du visage',
#  'Profil',
#  'Profil nasal',
#  'Profondeur',
#  'Profondeur du visage',
#  'Projection',
#  'Projection du menton',
#  'Proportions',
#  'Proportions du visage',
#  'Proéminence',
#  'Proéminence des pommettes',
#  'Racine',
#  'Racine du nez',
#  'Rides',
#  'Rides du front',
#  'Rides du visage',
#  'Rides d’expression',
#  'Rond',
#  'Rond des joues',
#  'Sourcils',
#  'Sourire',
#  'Structure',
#  'Structure faciale',
#  'Symétrie',
#  'Symétrie faciale',
#  'Taches',
#  'Taches de rousseur',
#  'Taches pigmentaires',
#  'Taille',
#  'Taille des oreilles',
#  'Taille des yeux',
#  'Teint',
#  'Tempes',
#  'Texture',
#  'Texture de la peau',
#  'Tissus',
#  'Tissus mous du visage',
#  'Traits',
#  'Traits du visage',
#  'Visage',
#  'Visage joufflu',
#  'Visage émacié',
#  'Volume',
#  'Volume des joues',
#  'Yeux',
#  'alignement',
#  'alignement des dents',
#  'alignement du visage',
#  'analyse',
#  'analyse du visage',
#  'angle',
#  'angle de la mâchoire',
#  'angle du menton',
#  'angle du nez',
#  'asymétrie',
#  'asymétrie des lèvres',
#  'asymétrie des oreilles',
#  'asymétrie faciale',
#  'auriculaire',
#  'barbe',
#  'base',
#  'base du nez',
#  'beauté',
#  'bosses',
#  'bosses frontales',
#  'bouche',
#  'capillaire',
#  'cartilage',
#  'cartilage auriculaire',
#  'cernes',
#  'cernes sous les yeux',
#  'cicatrices',
#  'cicatrices faciales',
#  'cils',
#  'contour',
#  'contour de la mâchoire',
#  'contours',
#  'contours des lèvres',
#  'contours du visage',
#  'couleur',
#  'couleur des yeux',
#  'courbure',
#  'courbure des sourcils',
#  'creux',
#  'creux des joues',
#  'cupidon',
#  'cupidon des lèvres',
#  "d'oreilles",
#  'densité',
#  'densité des sourcils',
#  'dents',
#  'distance',
#  'distance interoculaire',
#  'distance sourcils',
#  'distance sourcils-yeux',
#  'dorsum',
#  'dorsum nasal',
#  'dynamique',
#  'dynamique du visage',
#  'dégagé',
#  'd’expression',
#  'expression',
#  'expression du regard',
#  'expression faciale',
#  'faciale',
#  'faciales',
#  'forme',
#  'forme de la mâchoire',
#  'forme des lèvres',
#  'forme des oreilles',
#  'forme des yeux',
#  'forme du menton',
#  'forme du nez',
#  'forme du visage',
#  'fossette',
#  'fossette du menton',
#  'front',
#  'front dégagé',
#  'frontales',
#  'grain',
#  'grain de beauté',
#  'grain de peau',
#  'hauteur',
#  'hauteur des lèvres',
#  'hauteur des oreilles',
#  'hauteur des pommettes',
#  'hauteur du front',
#  'hauteur du nez',
#  'hauteur du visage',
#  'implantation',
#  'implantation capillaire',
#  'inclinaison',
#  'inclinaison des oreilles',
#  'inclinaison des yeux',
#  'inclinaison du front',
#  'interoculaire',
#  'joues',
#  'joufflu',
#  'largeur',
#  'largeur de la bouche',
#  'largeur de la mâchoire',
#  'largeur des oreilles',
#  'largeur des pommettes',
#  'largeur du front',
#  'largeur du menton',
#  'largeur du nez',
#  'largeur du visage',
#  'lignes',
#  'lignes du front',
#  'lobes',
#  "lobes d'oreilles",
#  'longueur',
#  'longueur du nez',
#  'longueur du visage',
#  'lèvres',
#  'l’oreille',
#  'mandibule',
#  'maxillaire',
#  'menton',
#  'mobilité',
#  'mobilité oculaire',
#  'morphologie',
#  'morphologie faciale',
#  'mous',
#  'moustache',
#  'mouvement',
#  'mouvement des lèvres',
#  'musculature',
#  'musculature faciale',
#  'mâchoire',
#  'narines',
#  'nasal',
#  'nez',
#  'oculaire',
#  'oreilles',
#  'os',
#  'os du visage',
#  'os zygomatique',
#  'paupières',
#  'peau',
#  'philtrum',
#  'photogrammétrie',
#  'photogrammétrie faciale',
#  'pigmentaires',
#  'pilosité',
#  'pilosité faciale',
#  'plis',
#  'plis de l’oreille',
#  'plis des paupières',
#  'poids',
#  'poids du visage',
#  'pointe',
#  'pointe du nez',
#  'pommettes',
#  'pores',
#  'pores du visage',
#  'position',
#  'position des oreilles',
#  'position des paupières',
#  'posture',
#  'posture du visage',
#  'profil',
#  'profil nasal',
#  'profondeur',
#  'profondeur du visage',
#  'projection',
#  'projection du menton',
#  'proportions',
#  'proportions du visage',
#  'proéminence',
#  'proéminence des pommettes',
#  'racine',
#  'racine du nez',
#  'regard',
#  'rides',
#  'rides du front',
#  'rides du visage',
#  'rides d’expression',
#  'rond',
#  'rond des joues',
#  'rousseur',
#  'sourcils',
#  'sourcils-yeux',
#  'sourire',
#  'structure',
#  'structure faciale',
#  'symétrie',
#  'symétrie faciale',
#  'taches',
#  'taches de rousseur',
#  'taches pigmentaires',
#  'taille',
#  'taille des oreilles',
#  'taille des yeux',
#  'teint',
#  'tempes',
#  'texture',
#  'texture de la peau',
#  'tissus',
#  'tissus mous du visage',
#  'traits',
#  'traits du visage',
#  'visage',
#  'visage joufflu',
#  'visage émacié',
#  'volume',
#  'volume des joues',
#  'yeux',
#  'zygomatique',
#  'Écartement',
#  'Écartement des narines',
#  'Écartement des yeux',
#  'Épaisseur',
#  'Épaisseur des lèvres',
#  'Épaisseur des sourcils',
#  'écartement',
#  'écartement des narines',
#  'écartement des yeux',
#  'émacié',
#  'épaisseur',
#  'épaisseur des lèvres',
#  'épaisseur des sourcils']

# %% [markdown]
# # HAIR

# %%
conviction = list(health["HAIR"].dropna())
conviction_split  = [conv.split() for conv in conviction]
conviction_split_joined = [item for lst in conviction_split for item  in lst]
conviction.extend(conviction_split_joined)

conviction = [word for word in  conviction if word not in french_stopwords]
split = [sub.split("-") for sub in conviction if '-' in sub]
new_subcat = [item for lst in split for item in lst]
conviction.extend(new_subcat)

conviction_lower = [word.lower() for word in conviction]
conviction.extend(conviction_lower)

conviction = [word for word in  conviction if word not in french_stopwords]
hair = set(conviction)
sorted(hair)
# Out:
# ['Alopécie',
#  'Alopécie partielle',
#  'Alopécie totale',
#  'Auburn',
#  'Blond',
#  'Blond cendré',
#  'Blond clair',
#  'Blond foncé',
#  'Blond platine',
#  'Blond vénitien',
#  'Boucles',
#  'Boucles définies',
#  'Calvitie',
#  'Calvitie avancée',
#  'Calvitie naissante',
#  'Carré',
#  'Carré court',
#  'Carré long',
#  'Cheveux',
#  'Cheveux abîmés',
#  'Cheveux afro',
#  'Cheveux attachés',
#  'Cheveux blancs',
#  'Cheveux bleus',
#  'Cheveux blonds',
#  'Cheveux bouclés',
#  'Cheveux brillants',
#  'Cheveux bruns',
#  'Cheveux brûlés par la chaleur',
#  'Cheveux cassants',
#  'Cheveux châtains',
#  'Cheveux clairsemés',
#  'Cheveux colorés',
#  'Cheveux courts',
#  'Cheveux crantés',
#  'Cheveux crépus',
#  'Cheveux denses',
#  'Cheveux déshydratés',
#  'Cheveux en bataille',
#  'Cheveux en bonne santé',
#  'Cheveux en brosse',
#  'Cheveux fins',
#  'Cheveux fins et fragiles',
#  'Cheveux fourchus',
#  'Cheveux frisés',
#  'Cheveux gominés',
#  'Cheveux gras',
#  'Cheveux gras aux racines',
#  'Cheveux gris',
#  'Cheveux hydratés',
#  'Cheveux lisses',
#  'Cheveux longs',
#  'Cheveux mi',
#  'Cheveux mi-longs',
#  'Cheveux multicolores',
#  'Cheveux noirs',
#  'Cheveux normaux',
#  'Cheveux ondulés',
#  'Cheveux poreux',
#  'Cheveux raides',
#  'Cheveux rasés',
#  'Cheveux roses',
#  'Cheveux roux',
#  'Cheveux rugueux',
#  'Cheveux secs',
#  'Cheveux secs et cassants',
#  'Cheveux soyeux',
#  'Cheveux ternes',
#  'Cheveux ternes et sans éclat',
#  'Cheveux texturés',
#  'Cheveux très courts',
#  'Cheveux très longs',
#  'Cheveux verts',
#  'Cheveux violets',
#  'Cheveux volumineux',
#  'Cheveux épais',
#  'Chignon',
#  'Chignon bas',
#  'Chignon haut',
#  'Chute',
#  'Chute de cheveux',
#  'Châtain',
#  'Châtain clair',
#  'Châtain foncé',
#  'Chéloïdes',
#  'Chéloïdes du cuir chevelu',
#  'Coiffure',
#  'Coiffure en dreadlocks',
#  'Coupe',
#  'Coupe au carré',
#  'Coupe buzz cut',
#  'Coupe dégradée',
#  'Coupe militaire',
#  'Coupe mulet',
#  'Coupe pixie',
#  'Coupe à la garçonne',
#  'Cuir',
#  'Cuir chevelu irrité',
#  'Dégradé',
#  'Dégradé court',
#  'Dégradé long',
#  'Démangeaisons',
#  'Démangeaisons du cuir chevelu',
#  'Entrées',
#  'Entrées prononcées',
#  'Faible',
#  'Faible densité capillaire',
#  'Forte',
#  'Forte densité capillaire',
#  'Frange',
#  'Frange asymétrique',
#  'Frange droite',
#  'Frange effilée',
#  'Frange rideau',
#  'Front',
#  'Front dégagé',
#  'Gris',
#  'Gris argenté',
#  'Gris cendré',
#  'Ligne',
#  'Ligne capillaire droite',
#  'Ligne capillaire en V',
#  'Ligne capillaire reculée',
#  'Mèches',
#  'Mèches balayées',
#  'Mèches colorées',
#  'Nattes',
#  'Pellicules',
#  'Perte',
#  'Perte de cheveux hormonale',
#  'Perte de cheveux saisonnière',
#  'Poivre',
#  'Poivre et sel',
#  'Queue',
#  'Queue de cheval',
#  'Roux',
#  'Roux clair',
#  'Roux foncé',
#  'Sensibilité',
#  'Sensibilité du cuir chevelu',
#  'Tempes',
#  'Tempes dégarnies',
#  'Tresse',
#  'Tresses',
#  'Tresses africaines',
#  'Tresses box braids',
#  'Tresses collées',
#  'Type',
#  'Type de cheveux:',
#  'Undercut',
#  'V',
#  'Vanilles',
#  'abîmés',
#  'africaines',
#  'afro',
#  'alopécie',
#  'alopécie partielle',
#  'alopécie totale',
#  'argenté',
#  'asymétrique',
#  'attachés',
#  'auburn',
#  'avancée',
#  'balayées',
#  'bataille',
#  'blancs',
#  'bleus',
#  'blond',
#  'blond cendré',
#  'blond clair',
#  'blond foncé',
#  'blond platine',
#  'blond vénitien',
#  'blonds',
#  'bonne',
#  'boucles',
#  'boucles définies',
#  'bouclés',
#  'box',
#  'braids',
#  'brillants',
#  'brosse',
#  'bruns',
#  'brûlés',
#  'buzz',
#  'calvitie',
#  'calvitie avancée',
#  'calvitie naissante',
#  'capillaire',
#  'carré',
#  'carré court',
#  'carré long',
#  'cassants',
#  'cendré',
#  'chaleur',
#  'cheval',
#  'chevelu',
#  'cheveux',
#  'cheveux abîmés',
#  'cheveux afro',
#  'cheveux attachés',
#  'cheveux blancs',
#  'cheveux bleus',
#  'cheveux blonds',
#  'cheveux bouclés',
#  'cheveux brillants',
#  'cheveux bruns',
#  'cheveux brûlés par la chaleur',
#  'cheveux cassants',
#  'cheveux châtains',
#  'cheveux clairsemés',
#  'cheveux colorés',
#  'cheveux courts',
#  'cheveux crantés',
#  'cheveux crépus',
#  'cheveux denses',
#  'cheveux déshydratés',
#  'cheveux en bataille',
#  'cheveux en bonne santé',
#  'cheveux en brosse',
#  'cheveux fins',
#  'cheveux fins et fragiles',
#  'cheveux fourchus',
#  'cheveux frisés',
#  'cheveux gominés',
#  'cheveux gras',
#  'cheveux gras aux racines',
#  'cheveux gris',
#  'cheveux hydratés',
#  'cheveux lisses',
#  'cheveux longs',
#  'cheveux mi',
#  'cheveux mi-longs',
#  'cheveux multicolores',
#  'cheveux noirs',
#  'cheveux normaux',
#  'cheveux ondulés',
#  'cheveux poreux',
#  'cheveux raides',
#  'cheveux rasés',
#  'cheveux roses',
#  'cheveux roux',
#  'cheveux rugueux',
#  'cheveux secs',
#  'cheveux secs et cassants',
#  'cheveux soyeux',
#  'cheveux ternes',
#  'cheveux ternes et sans éclat',
#  'cheveux texturés',
#  'cheveux très courts',
#  'cheveux très longs',
#  'cheveux verts',
#  'cheveux violets',
#  'cheveux volumineux',
#  'cheveux épais',
#  'cheveux:',
#  'chignon',
#  'chignon bas',
#  'chignon haut',
#  'chute',
#  'chute de cheveux',
#  'châtain',
#  'châtain clair',
#  'châtain foncé',
#  'châtains',
#  'chéloïdes',
#  'chéloïdes du cuir chevelu',
#  'clair',
#  'clairsemés',
#  'coiffure',
#  'coiffure en dreadlocks',
#  'collées',
#  'colorées',
#  'colorés',
#  'coupe',
#  'coupe au carré',
#  'coupe buzz cut',
#  'coupe dégradée',
#  'coupe militaire',
#  'coupe mulet',
#  'coupe pixie',
#  'coupe à la garçonne',
#  'court',
#  'courts',
#  'crantés',
#  'crépus',
#  'cuir',
#  'cuir chevelu irrité',
#  'cut',
#  'denses',
#  'densité',
#  'dreadlocks',
#  'droite',
#  'définies',
#  'dégagé',
#  'dégarnies',
#  'dégradé',
#  'dégradé court',
#  'dégradé long',
#  'dégradée',
#  'démangeaisons',
#  'démangeaisons du cuir chevelu',
#  'déshydratés',
#  'effilée',
#  'entrées',
#  'entrées prononcées',
#  'faible',
#  'faible densité capillaire',
#  'fins',
#  'foncé',
#  'forte',
#  'forte densité capillaire',
#  'fourchus',
#  'fragiles',
#  'frange',
#  'frange asymétrique',
#  'frange droite',
#  'frange effilée',
#  'frange rideau',
#  'frisés',
#  'front',
#  'front dégagé',
#  'garçonne',
#  'gominés',
#  'gras',
#  'gris',
#  'gris argenté',
#  'gris cendré',
#  'haut',
#  'hormonale',
#  'hydratés',
#  'irrité',
#  'ligne',
#  'ligne capillaire droite',
#  'ligne capillaire en v',
#  'ligne capillaire reculée',
#  'lisses',
#  'long',
#  'longs',
#  'mi',
#  'mi-longs',
#  'militaire',
#  'mulet',
#  'multicolores',
#  'mèches',
#  'mèches balayées',
#  'mèches colorées',
#  'naissante',
#  'nattes',
#  'noirs',
#  'normaux',
#  'ondulés',
#  'partielle',
#  'pellicules',
#  'perte',
#  'perte de cheveux hormonale',
#  'perte de cheveux saisonnière',
#  'pixie',
#  'platine',
#  'poivre',
#  'poivre et sel',
#  'poreux',
#  'prononcées',
#  'queue',
#  'queue de cheval',
#  'racines',
#  'raides',
#  'rasés',
#  'reculée',
#  'rideau',
#  'roses',
#  'roux',
#  'roux clair',
#  'roux foncé',
#  'rugueux',
#  'saisonnière',
#  'santé',
#  'secs',
#  'sel',
#  'sensibilité',
#  'sensibilité du cuir chevelu',
#  'soyeux',
#  'tempes',
#  'tempes dégarnies',
#  'ternes',
#  'texturés',
#  'totale',
#  'tresse',
#  'tresses',
#  'tresses africaines',
#  'tresses box braids',
#  'tresses collées',
#  'type',
#  'type de cheveux:',
#  'undercut',
#  'v',
#  'vanilles',
#  'verts',
#  'violets',
#  'volumineux',
#  'vénitien',
#  'éclat',
#  'épais']

# %% [markdown]
# # PHYSICAL_DESCRIPTION

# %%
conviction = list(health["PHYSICAL_DESCRIPTION"].dropna())
conviction_split  = [conv.split() for conv in conviction]
conviction_split_joined = [item for lst in conviction_split for item  in lst]
conviction.extend(conviction_split_joined)

conviction = [word for word in  conviction if word not in french_stopwords]
split = [sub.split("-") for sub in conviction if '-' in sub]
new_subcat = [item for lst in split for item in lst]
conviction.extend(new_subcat)

conviction_lower = [word.lower() for word in conviction]
conviction.extend(conviction_lower)

conviction = [word for word in  conviction if word not in french_stopwords]
physical = set(conviction)
sorted(physical)
# Out:
# ['Albinos',
#  'Allongé',
#  'Athlétique',
#  'Beige',
#  'Bouche',
#  'Bouche charnue',
#  'Bouche fine',
#  'Bouche large',
#  'Bouche pulpeuse',
#  'Brun',
#  'Carré',
#  'Cicatrices',
#  'Clair',
#  'Corps',
#  'Corps athlétique',
#  'Corps enrobé',
#  'Corps maigre',
#  'Corps musclé',
#  'Corps trapu',
#  'Corpulent',
#  'Doigts',
#  'Doigts agiles',
#  'Doigts courts',
#  'Doigts fins',
#  'Doigts longs',
#  'Doigts noueux',
#  'Doigts tremblants',
#  'Doigts épais',
#  'Dos',
#  'Dos droit',
#  'Dos voûté',
#  'Démarche',
#  'Démarche assurée',
#  'Démarche lente',
#  'Démarche lourde',
#  'Démarche légère',
#  'Démarche rapide',
#  'Démarche sautillante',
#  'Démarche traînante',
#  'En',
#  'En forme de cœur',
#  'En forme de diamant',
#  'Enrobé',
#  'Fin',
#  'Foncé',
#  'Grains',
#  'Grains de beauté',
#  'Grand',
#  'Grand nez',
#  'Hâlé',
#  'Jaunâtre',
#  'Large',
#  "Large d'épaules",
#  'Lourd',
#  'Lèvres',
#  'Lèvres asymétriques',
#  'Lèvres bien dessinées',
#  'Lèvres foncées',
#  'Lèvres gercées',
#  'Lèvres minces',
#  'Lèvres rosées',
#  'Lèvres rouges',
#  'Lèvres épaisses',
#  'Léger',
#  'Maigre',
#  'Mains',
#  'Mains fines',
#  'Mains larges',
#  'Mains osseuses',
#  'Mains potelées',
#  'Mat',
#  'Menton',
#  'Menton arrondi',
#  'Menton avec fossette',
#  'Menton carré',
#  'Menton en galoche',
#  'Menton et mâchoire:',
#  'Menton fuyant',
#  'Menton large',
#  'Menton pointu',
#  'Mince',
#  'Moyenne',
#  'Musclé',
#  'Mâchoire',
#  'Mâchoire anguleuse',
#  'Mâchoire carrée',
#  'Mâchoire fine',
#  'Mâchoire prononcée',
#  'Nez',
#  'Nez aplati',
#  'Nez aquilin',
#  'Nez busqué',
#  'Nez cassé',
#  'Nez crochu',
#  'Nez droit',
#  'Nez fin',
#  'Nez large',
#  'Nez pointu',
#  'Nez retroussé',
#  'Nez épaté',
#  'Noir',
#  'Obèse',
#  'Olive',
#  'Oreilles',
#  'Oreilles asymétriques',
#  'Oreilles collées',
#  'Oreilles décollées',
#  'Oreilles en chou',
#  'Oreilles grandes',
#  'Oreilles petites',
#  'Oreilles pointues',
#  'Oreilles rondes',
#  'Oreilles symétriques',
#  'Osseux',
#  'Ovale',
#  'Peau',
#  'Peau acnéique',
#  'Peau avec cicatrices',
#  'Peau avec grains de beauté',
#  'Peau avec taches de rousseur',
#  'Peau avec tatouages',
#  'Peau avec verrues',
#  'Peau cicatrisée',
#  'Peau grasse',
#  'Peau lisse',
#  'Peau marquée',
#  'Peau mixte',
#  'Peau ridée',
#  'Peau sensible',
#  'Peau sèche',
#  'Petit',
#  'Petit nez',
#  'Piercings',
#  'Poids',
#  'Poids moyen',
#  'Poids normal',
#  'Poids plume',
#  'Posture',
#  'Posture négligée',
#  'Posture élégante',
#  'Pâle',
#  'Rectangulaire',
#  'Rond',
#  'Rosé',
#  'Rougeaud',
#  'Sourcils',
#  'Sourcils arqués',
#  'Sourcils asymétriques',
#  'Sourcils broussailleux',
#  'Sourcils clairsemés',
#  'Sourcils droits',
#  'Sourcils en accent circonflexe',
#  'Sourcils fins',
#  'Sourcils épais',
#  'Surpoids',
#  'Svelte',
#  'Taches',
#  'Taches pigmentaires',
#  'Tatouages',
#  'Trapu',
#  'Triangulaire',
#  'Très',
#  'Très grand',
#  'Très petit',
#  'Tâches',
#  'Tâches de naissance',
#  'Verrues',
#  'Vitiligo',
#  'Yeux',
#  'Yeux bleu azur',
#  'Yeux bleu clair',
#  'Yeux bleu foncé',
#  'Yeux bleu gris',
#  'Yeux bleu océan',
#  'Yeux bleu saphir',
#  'Yeux bleu turquoise',
#  'Yeux bridés',
#  'Yeux bruns',
#  'Yeux doux',
#  'Yeux en amande',
#  'Yeux enfoncés',
#  'Yeux expressifs',
#  'Yeux fatigués',
#  'Yeux globuleux',
#  'Yeux grands',
#  'Yeux gris',
#  'Yeux gris bleu',
#  'Yeux gris clair',
#  'Yeux gris foncé',
#  'Yeux gris vert',
#  'Yeux hétérochromes',
#  'Yeux marron',
#  'Yeux mélancoliques',
#  'Yeux noirs',
#  'Yeux noisette',
#  'Yeux perçants',
#  'Yeux petits',
#  'Yeux rapprochés',
#  'Yeux ronds',
#  'Yeux tombants',
#  'Yeux vairons',
#  'Yeux vert jade',
#  'Yeux vert mousse',
#  'Yeux vert olive',
#  'Yeux vert émeraude',
#  'Yeux verts',
#  'Yeux vifs',
#  'Yeux écartés',
#  'accent',
#  'acnéique',
#  'agiles',
#  'albinos',
#  'allongé',
#  'amande',
#  'anguleuse',
#  'aplati',
#  'aquilin',
#  'arqués',
#  'arrondi',
#  'assurée',
#  'asymétriques',
#  'athlétique',
#  'azur',
#  'beauté',
#  'beige',
#  'bien',
#  'bleu',
#  'bouche',
#  'bouche charnue',
#  'bouche fine',
#  'bouche large',
#  'bouche pulpeuse',
#  'bridés',
#  'broussailleux',
#  'brun',
#  'bruns',
#  'busqué',
#  'carré',
#  'carrée',
#  'cassé',
#  'charnue',
#  'chou',
#  'cicatrices',
#  'cicatrisée',
#  'circonflexe',
#  'clair',
#  'clairsemés',
#  'collées',
#  'corps',
#  'corps athlétique',
#  'corps enrobé',
#  'corps maigre',
#  'corps musclé',
#  'corps trapu',
#  'corpulent',
#  'courts',
#  'crochu',
#  'cœur',
#  "d'épaules",
#  'dessinées',
#  'diamant',
#  'doigts',
#  'doigts agiles',
#  'doigts courts',
#  'doigts fins',
#  'doigts longs',
#  'doigts noueux',
#  'doigts tremblants',
#  'doigts épais',
#  'dos',
#  'dos droit',
#  'dos voûté',
#  'doux',
#  'droit',
#  'droits',
#  'décollées',
#  'démarche',
#  'démarche assurée',
#  'démarche lente',
#  'démarche lourde',
#  'démarche légère',
#  'démarche rapide',
#  'démarche sautillante',
#  'démarche traînante',
#  'en forme de cœur',
#  'en forme de diamant',
#  'enfoncés',
#  'enrobé',
#  'expressifs',
#  'fatigués',
#  'fin',
#  'fine',
#  'fines',
#  'fins',
#  'foncé',
#  'foncées',
#  'forme',
#  'fossette',
#  'fuyant',
#  'galoche',
#  'gercées',
#  'globuleux',
#  'grains',
#  'grains de beauté',
#  'grand',
#  'grand nez',
#  'grandes',
#  'grands',
#  'grasse',
#  'gris',
#  'hâlé',
#  'hétérochromes',
#  'jade',
#  'jaunâtre',
#  'large',
#  "large d'épaules",
#  'larges',
#  'lente',
#  'lisse',
#  'longs',
#  'lourd',
#  'lourde',
#  'lèvres',
#  'lèvres asymétriques',
#  'lèvres bien dessinées',
#  'lèvres foncées',
#  'lèvres gercées',
#  'lèvres minces',
#  'lèvres rosées',
#  'lèvres rouges',
#  'lèvres épaisses',
#  'léger',
#  'légère',
#  'maigre',
#  'mains',
#  'mains fines',
#  'mains larges',
#  'mains osseuses',
#  'mains potelées',
#  'marquée',
#  'marron',
#  'mat',
#  'menton',
#  'menton arrondi',
#  'menton avec fossette',
#  'menton carré',
#  'menton en galoche',
#  'menton et mâchoire:',
#  'menton fuyant',
#  'menton large',
#  'menton pointu',
#  'mince',
#  'minces',
#  'mixte',
#  'mousse',
#  'moyen',
#  'moyenne',
#  'musclé',
#  'mâchoire',
#  'mâchoire anguleuse',
#  'mâchoire carrée',
#  'mâchoire fine',
#  'mâchoire prononcée',
#  'mâchoire:',
#  'mélancoliques',
#  'naissance',
#  'nez',
#  'nez aplati',
#  'nez aquilin',
#  'nez busqué',
#  'nez cassé',
#  'nez crochu',
#  'nez droit',
#  'nez fin',
#  'nez large',
#  'nez pointu',
#  'nez retroussé',
#  'nez épaté',
#  'noir',
#  'noirs',
#  'noisette',
#  'normal',
#  'noueux',
#  'négligée',
#  'obèse',
#  'océan',
#  'olive',
#  'oreilles',
#  'oreilles asymétriques',
#  'oreilles collées',
#  'oreilles décollées',
#  'oreilles en chou',
#  'oreilles grandes',
#  'oreilles petites',
#  'oreilles pointues',
#  'oreilles rondes',
#  'oreilles symétriques',
#  'osseuses',
#  'osseux',
#  'ovale',
#  'peau',
#  'peau acnéique',
#  'peau avec cicatrices',
#  'peau avec grains de beauté',
#  'peau avec taches de rousseur',
#  'peau avec tatouages',
#  'peau avec verrues',
#  'peau cicatrisée',
#  'peau grasse',
#  'peau lisse',
#  'peau marquée',
#  'peau mixte',
#  'peau ridée',
#  'peau sensible',
#  'peau sèche',
#  'perçants',
#  'petit',
#  'petit nez',
#  'petites',
#  'petits',
#  'piercings',
#  'pigmentaires',
#  'plume',
#  'poids',
#  'poids moyen',
#  'poids normal',
#  'poids plume',
#  'pointu',
#  'pointues',
#  'posture',
#  'posture négligée',
#  'posture élégante',
#  'potelées',
#  'prononcée',
#  'pulpeuse',
#  'pâle',
#  'rapide',
#  'rapprochés',
#  'rectangulaire',
#  'retroussé',
#  'ridée',
#  'rond',
#  'rondes',
#  'ronds',
#  'rosé',
#  'rosées',
#  'rougeaud',
#  'rouges',
#  'rousseur',
#  'saphir',
#  'sautillante',
#  'sensible',
#  'sourcils',
#  'sourcils arqués',
#  'sourcils asymétriques',
#  'sourcils broussailleux',
#  'sourcils clairsemés',
#  'sourcils droits',
#  'sourcils en accent circonflexe',
#  'sourcils fins',
#  'sourcils épais',
#  'surpoids',
#  'svelte',
#  'symétriques',
#  'sèche',
#  'taches',
#  'taches pigmentaires',
#  'tatouages',
#  'tombants',
#  'trapu',
#  'traînante',
#  'tremblants',
#  'triangulaire',
#  'très grand',
#  'très petit',
#  'turquoise',
#  'tâches',
#  'tâches de naissance',
#  'vairons',
#  'verrues',
#  'vert',
#  'verts',
#  'vifs',
#  'vitiligo',
#  'voûté',
#  'yeux',
#  'yeux bleu azur',
#  'yeux bleu clair',
#  'yeux bleu foncé',
#  'yeux bleu gris',
#  'yeux bleu océan',
#  'yeux bleu saphir',
#  'yeux bleu turquoise',
#  'yeux bridés',
#  'yeux bruns',
#  'yeux doux',
#  'yeux en amande',
#  'yeux enfoncés',
#  'yeux expressifs',
#  'yeux fatigués',
#  'yeux globuleux',
#  'yeux grands',
#  'yeux gris',
#  'yeux gris bleu',
#  'yeux gris clair',
#  'yeux gris foncé',
#  'yeux gris vert',
#  'yeux hétérochromes',
#  'yeux marron',
#  'yeux mélancoliques',
#  'yeux noirs',
#  'yeux noisette',
#  'yeux perçants',
#  'yeux petits',
#  'yeux rapprochés',
#  'yeux ronds',
#  'yeux tombants',
#  'yeux vairons',
#  'yeux vert jade',
#  'yeux vert mousse',
#  'yeux vert olive',
#  'yeux vert émeraude',
#  'yeux verts',
#  'yeux vifs',
#  'yeux écartés',
#  'écartés',
#  'élégante',
#  'émeraude',
#  'épais',
#  'épaisses',
#  'épaté']

# %% [markdown]
# # DATAFRAME

# %%
df = pd.DataFrame(zip_longest(face, hair, physical), columns=["FACE_FEATURES","HAIR","PHYSICAL_DESCRIPTION"])
df.to_excel(new_file_path,sheet_name="BIOMETRICS", index=False)
