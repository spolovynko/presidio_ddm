# %%
import pandas as pd
import spacy
from itertools import zip_longest
import re

file_path = r"C:\Users\spolo\OneDrive\Documents\DOC\Work\TCS\Code\dynamic_data_masking\presidio_ddm\deny_list_dataset\deny_list_tokens_ddm.xlsx"
new_file_path = r"C:\Users\spolo\OneDrive\Documents\DOC\Work\TCS\Code\dynamic_data_masking\presidio_ddm\deny_list_dataset\deny_list_tokens_c4_v1.xlsx"

df = pd.read_excel(file_path, sheet_name="HEALTH")

nlp = spacy.load("fr_core_news_lg")
french_stopwords = nlp.Defaults.stop_words

# %%
import pandas as pd
from itertools import zip_longest

def augmentation(df, french_stopwords):
    new_df_columns = {}

    for col in df.columns:
        new_column = list(df[col].dropna())  # Remove NaN values

        # Split words by space
        new_column_split = [conv.split() for conv in new_column]
        new_column_split_joined = [item for lst in new_column_split for item in lst]
        new_column.extend(new_column_split_joined)

        # Remove French stopwords
        new_column = [word for word in new_column if word.lower() not in french_stopwords]

        # Handle hyphenated words
        split = [sub.split("-") for sub in new_column if '-' in sub]
        new_subcat = [item for lst in split for item in lst]
        new_column.extend(new_subcat)

        # Lowercase transformation
        new_column_lower = [word.lower() for word in new_column]
        new_column.extend(new_column_lower)

        # Remove stopwords again after modifications
        new_column = [word for word in new_column if word.lower() not in french_stopwords]

        # Convert to unique sorted list
        new_column = sorted(set(new_column))

        # Store results in dictionary (column_name: column_values)
        new_df_columns[col] = new_column

    # Make all columns the same length using zip_longest
    max_length = max(len(v) for v in new_df_columns.values())
    for col in new_df_columns:
        new_df_columns[col] += [None] * (max_length - len(new_df_columns[col]))  # Padding with None

    # Convert dictionary to DataFrame
    new_df = pd.DataFrame(new_df_columns)

    return new_df


new_df = augmentation(df, french_stopwords)

with pd.ExcelWriter(new_file_path, mode='a', if_sheet_exists='new', engine='openpyxl') as writer:
    new_df.to_excel(writer, sheet_name='HEALTH', index=False)

# %% [markdown]
# # DISEASE

# %%
conviction = list(health["DISEASE"].dropna())
conviction_split  = [conv.split() for conv in conviction]
conviction_split_joined = [item for lst in conviction_split for item  in lst]
conviction.extend(conviction_split_joined)

conviction = [word for word in  conviction if word not in french_stopwords]
split = [sub.split("-") for sub in conviction if '-' in sub]
new_subcat = [item for lst in split for item in lst]
conviction.extend(new_subcat)

conviction_lower = [word.lower() for word in conviction]
conviction.extend(conviction_lower)

conviction = [word for word in  conviction if word not in french_stopwords]
conviction = set(conviction)

# %% [markdown]
# # SYMPTOM

# %%
conviction = list(health["SYMPTOM"].dropna())
conviction_split  = [conv.split() for conv in conviction]
conviction_split_joined = [item for lst in conviction_split for item  in lst]
conviction.extend(conviction_split_joined)

conviction = [word for word in  conviction if word not in french_stopwords]
split = [sub.split("-") for sub in conviction if '-' in sub]
new_subcat = [item for lst in split for item in lst]
conviction.extend(new_subcat)

conviction_lower = [word.lower() for word in conviction]
conviction.extend(conviction_lower)

conviction = [word for word in  conviction if word not in french_stopwords]
conviction = set(conviction)

# %% [markdown]
# # TREATMENT

# %%
conviction = list(health["TREATMENT"].dropna())
conviction_split  = [conv.split() for conv in conviction]
conviction_split_joined = [item for lst in conviction_split for item  in lst]
conviction.extend(conviction_split_joined)

conviction = [word for word in  conviction if word not in french_stopwords]
split = [sub.split("-") for sub in conviction if '-' in sub]
new_subcat = [item for lst in split for item in lst]
conviction.extend(new_subcat)

conviction_lower = [word.lower() for word in conviction]
conviction.extend(conviction_lower)

conviction = [word for word in  conviction if word not in french_stopwords]
conviction = set(conviction)

# %% [markdown]
# # MEDICATION

# %%
conviction = list(health["MEDICATION"].dropna())
conviction_split  = [conv.split() for conv in conviction]
conviction_split_joined = [item for lst in conviction_split for item  in lst]
conviction.extend(conviction_split_joined)

conviction = [word for word in  conviction if word not in french_stopwords]
split = [sub.split("-") for sub in conviction if '-' in sub]
new_subcat = [item for lst in split for item in lst]
conviction.extend(new_subcat)

conviction_lower = [word.lower() for word in conviction]
conviction.extend(conviction_lower)

conviction = [word for word in  conviction if word not in french_stopwords]
conviction = set(conviction)

# %% [markdown]
# # DIAGNOSIS

# %%
conviction = list(health["DIAGNOSIS"].dropna())
conviction_split  = [conv.split() for conv in conviction]
conviction_split_joined = [item for lst in conviction_split for item  in lst]
conviction.extend(conviction_split_joined)

conviction = [word for word in  conviction if word not in french_stopwords]
split = [sub.split("-") for sub in conviction if '-' in sub]
new_subcat = [item for lst in split for item in lst]
conviction.extend(new_subcat)

conviction_lower = [word.lower() for word in conviction]
conviction.extend(conviction_lower)

conviction = [word for word in  conviction if word not in french_stopwords]
conviction = set(conviction)

# %% [markdown]
# # THERAPIST

# %%
conviction = list(health["THERAPIST"].dropna())
conviction_split  = [conv.split() for conv in conviction]
conviction_split_joined = [item for lst in conviction_split for item  in lst]
conviction.extend(conviction_split_joined)

conviction = [word for word in  conviction if word not in french_stopwords]
split = [sub.split("-") for sub in conviction if '-' in sub]
new_subcat = [item for lst in split for item in lst]
conviction.extend(new_subcat)

conviction_lower = [word.lower() for word in conviction]
conviction.extend(conviction_lower)

conviction = [word for word in  conviction if word not in french_stopwords]
conviction = set(conviction)

# %% [markdown]
# # VACCINE

# %%
conviction = list(health["VACCINE"].dropna())
conviction_split  = [conv.split() for conv in conviction]
conviction_split_joined = [item for lst in conviction_split for item  in lst]
conviction.extend(conviction_split_joined)

conviction = [word for word in  conviction if word not in french_stopwords]
split = [sub.split("-") for sub in conviction if '-' in sub]
new_subcat = [item for lst in split for item in lst]
conviction.extend(new_subcat)

conviction_lower = [word.lower() for word in conviction]
conviction.extend(conviction_lower)

conviction = [word for word in  conviction if word not in french_stopwords]
conviction = set(conviction)

# %% [markdown]
# # SURGERY

# %%
health.columns
# Out:
# Index(['DISEASE', 'SYMPTOM', 'TREATMENT', 'MEDICATION', 'DIAGNOSIS',
#        'THERAPIST', 'VACCINE', 'SURGERY ', 'MENTAL_HEALTH'],
#       dtype='object')

# %%
conviction = list(health["SURGERY "].dropna())
conviction_split  = [conv.split() for conv in conviction]
conviction_split_joined = [item for lst in conviction_split for item  in lst]
conviction.extend(conviction_split_joined)

conviction = [word for word in  conviction if word not in french_stopwords]
split = [sub.split("-") for sub in conviction if '-' in sub]
new_subcat = [item for lst in split for item in lst]
conviction.extend(new_subcat)

conviction_lower = [word.lower() for word in conviction]
conviction.extend(conviction_lower)

conviction = [word for word in  conviction if word not in french_stopwords]
conviction = set(conviction)

# %%
health
# Out:
#                   DISEASE        SYMPTOM     TREATMENT  \
# 0     Maladie d'Alzheimer         Fièvre   Paracétamol
# 1    Maladie de Parkinson       Frissons    Ibuprofène
# 2        Maladie de Crohn           Toux      Aspirine
# 3        Maladie cœliaque   Éternuements  Amoxicilline
# 4         Maladie de Lyme  Essoufflement      Morphine
# ..                    ...            ...           ...
# 570                   NaN            NaN           NaN
# 571                   NaN            NaN           NaN
# 572                   NaN            NaN           NaN
# 573                   NaN            NaN           NaN
# 574                   NaN            NaN           NaN
#
#                   MEDICATION         DIAGNOSIS            THERAPIST  \
# 0    Acide acétylsalicylique    Abcès cérébral  Médecin généraliste
# 1              Acide folique    Abcès dentaire     Médecin traitant
# 2                 Adalimumab   Abcès hépatique   Médecin urgentiste
# 3                       AINS  Abcès pulmonaire      Médecin légiste
# 4                Alendronate       Abcès rénal     Médecin du sport
# ..                       ...               ...                  ...
# 570                      NaN               NaN                  NaN
# 571                      NaN               NaN                  NaN
# 572                      NaN               NaN                  NaN
# 573                      NaN               NaN                  NaN
# 574                      NaN               NaN                  NaN
#
#             VACCINE                   SURGERY   \
# 0            Vaccin                  Chirurgie
# 1       Vaccination                  Opération
# 2      Immunisation  Intervention chirurgicale
# 3             Sérum           Acte chirurgical
# 4    Dose de vaccin     Procédure chirurgicale
# ..              ...                        ...
# 570             NaN                        NaN
# 571             NaN                        NaN
# 572             NaN                        NaN
# 573             NaN                        NaN
# 574             NaN                        NaN
#
#                                   MENTAL_HEALTH
# 0                                 Santé mentale
# 1                                Trouble mental
# 2                         Trouble psychologique
# 3                         Trouble psychiatrique
# 4                           Trouble de l’humeur
# ..                                          ...
# 570              Traitement de la schizophrénie
# 571  Traitement des troubles de la personnalité
# 572          Trouble de l’identité émotionnelle
# 573   Trouble de la reconnaissance émotionnelle
# 574                         Vigilance excessive
#
# [575 rows x 9 columns]

# %% [markdown]
# # MENTAL_HEALTH

# %%
conviction = list(health["MENTAL_HEALTH"].dropna())
conviction_split  = [conv.split() for conv in conviction]
conviction_split_joined = [item for lst in conviction_split for item  in lst]
conviction.extend(conviction_split_joined)

conviction = [word for word in  conviction if word not in french_stopwords]
split = [sub.split("-") for sub in conviction if '-' in sub]
new_subcat = [item for lst in split for item in lst]
conviction.extend(new_subcat)

conviction_lower = [word.lower() for word in conviction]
conviction.extend(conviction_lower)

conviction = [word for word in  conviction if word not in french_stopwords]
conviction = set(conviction)
